# %%
def batch_predict_reviews(reviews):
    results = []
    for review in reviews:
        if 'good' in review.lower():
            results.append('positive')
        else:
            results.append('negative')
    return results
reviews_list = ['The food was really good and tasty.', 'Terrible service, I hated it.', 'A very good experience overall.', 'Not bad, but could be better.', 'Good ambiance and polite staff.', 'The worst food I have ever tasted.', 'It was a good meal for the price.', 'I will never order from here again.', 'Very good portion sizes.', 'Absolutely disgusting and cold.']
predictions = batch_predict_reviews(reviews_list)
for i in range(len(reviews_list)):
    print(f"Review: '{reviews_list[i]}' -> Prediction: {predictions[i]}")
# Out:
# Review: 'The food was really good and tasty.' -> Prediction: positive
# Review: 'Terrible service, I hated it.' -> Prediction: negative
# Review: 'A very good experience overall.' -> Prediction: positive
# Review: 'Not bad, but could be better.' -> Prediction: negative
# Review: 'Good ambiance and polite staff.' -> Prediction: positive
# Review: 'The worst food I have ever tasted.' -> Prediction: negative
# Review: 'It was a good meal for the price.' -> Prediction: positive
# Review: 'I will never order from here again.' -> Prediction: negative
# Review: 'Very good portion sizes.' -> Prediction: positive
# Review: 'Absolutely disgusting and cold.' -> Prediction: negative
